# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

service = Service(r'C:\Users\SaiManeeshKosuru\Downloads\chromedriver.exe')

def get_drvier():
  # Set options to make browsing easier
  options = webdriver.ChromeOptions()
  options.add_argument("disable-infobars")
  options.add_argument("start-maximized")
  options.add_argument("disable-dev-shm-usage")
  options.add_argument("no-sandbox")
  options.add_experimental_option("excludeSwitches", ["enable-automation"])
  options.add_argument("disable-blink-features=AutomationControlled")

  driver = webdriver.Chrome(options=options,service=service)
  driver.get("http://automated.pythonanywhere.com")
  return driver

def main():
  driver = get_drvier()
  element = driver.find_element(by="xpath", value="/html/body/div[1]/div/h1[1]")
  return element.text

print(main())
# Out:
# “For the things we have to learn before we can do them, we learn by doing them”- Aristotle

# %% [markdown]
# No we use click features of selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

service = Service(r'C:\Users\SaiManeeshKosuru\Downloads\chromedriver.exe')

def get_drvier():
      # Set options to make browsing easier
    options = webdriver.ChromeOptions()
    options.add_argument("disable-infobars")
    options.add_argument("start-maximized")
    options.add_argument("disable-dev-shm-usage")
    options.add_argument("no-sandbox")
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_argument("disable-blink-features=AutomationControlled")

    driver = webdriver.Chrome(options=options,service=service)
    driver.get("http://automated.pythonanywhere.com/login/")
    
    return driver


def main():
    driver = get_drvier()
    driver.find_element('xpath','/html/body/div[1]/div/div/div[3]/form/p[4]/input').send_keys('automated')
    time.sleep(1)
    driver.find_element('xpath','/html/body/div[1]/div/div/div[3]/form/p[7]/input').send_keys('automatedautomated')
    time.sleep(2)
    driver.find_element('xpath','/html/body/div[1]/div/div/div[3]/form/button').click()
    time.sleep(1)
    driver.find_element('xpath','/html/body/nav/div/a').click()
    time.sleep(2)
    return driver.find_element('xpath','/html/body/div[1]/div/h1[2]').text

# %% [markdown]
# small exercise same bullshit but i removed options

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

service = Service(executable_path=r'C:\Users\SaiManeeshKosuru\Downloads\chromedriver.exe')
def get_driver():
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--profile-directory=Default')
    chrome_options.add_argument("--incognito")
    chrome_options.add_argument("--disable-plugins-discovery");
    chrome_options.add_argument("--start-maximized")
    
    driver = webdriver.Chrome(service=service,options=chrome_options)
    driver.get('http://automated.pythonanywhere.com/login/')
    return driver

def main():
    username = 'automated'
    password = 'automatedautomated'
    driver = get_driver()
    time.sleep(3)
    driver.find_element('xpath','/html/body/div[1]/div/div/div[3]/form/p[4]/input').send_keys(username)
    time.sleep(2)
    driver.find_element('xpath','/html/body/div[1]/div/div/div[3]/form/p[7]/input').send_keys(password)
    time.sleep(1)
    driver.find_element('xpath','/html/body/div[1]/div/div/div[3]/form/button').click()
    time.sleep(2)
    driver.find_element('xpath','/html/body/nav/div/a').click()
    time.sleep(3)
    text =  driver.find_element('xpath','/html/body/div[1]/div/h1[2]').text
    return text.split(': ')[1]

# %%
import datetime
import os
default = r'C:\Users\SaiManeeshKosuru\Downloads\sample'

for _ in range(3):
    str_date = (str(datetime.datetime.now())+'.txt').replace(':','-')
    path = os.path.join(default,str_date)
    file = open(file=path,mode='w')
    file.write(main())
    file.close()

# %% [markdown]
#  titan 22.com

# %%
from selenium import webdriver
import time

service = webdriver.chrome.service.Service(executable_path=r'C:\Users\SaiManeeshKosuru\Downloads\chromedriver.exe')


def get_driver():
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--profile-directory=Default')
    chrome_options.add_argument("--incognito")
    chrome_options.add_argument("--disable-plugins-discovery");
    chrome_options.add_argument("--start-maximized")
    
    driver = webdriver.Chrome(options=chrome_options,service=service)
    driver.get('https://titan22.com/account/login?return_url=%2Faccount')
    return driver

def main():
    username = 'spam11031998@gmail.com'
    password = 'maneesh123'
    driver = get_driver()
    time.sleep(1)
    driver.find_element('xpath','/html/body/main/article/section/div/div[1]/form/div[1]/input').send_keys(username)
    time.sleep(1)
    driver.find_element('xpath','/html/body/main/article/section/div/div[1]/form/div[2]/input').send_keys(password)
    time.sleep(1)
    driver.find_element('xpath','/html/body/main/article/section/div/div[1]/form/button').click()
    time.sleep(3)
    driver.find_element('xpath','/html/body/footer/div/section/div/div[1]/div[1]/div[2]/nav/ul/li[2]/a').click()
    time.sleep(1)
    driver.find_element('xpath','/html/body/main/article/div[2]/div[6]/div/div[2]/div[3]/div/div[2]/div/div/div[1]/div[1]/div/h4').click()

# %%
main()

# %% [markdown]
# Now use udmey to make a mark

# %%
from selenium import webdriver
import time

service = webdriver.chrome.service.Service(executable_path=r'C:\Users\SaiManeeshKosuru\Downloads\chromedriver.exe')


def get_driver():
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--profile-directory=Default')
    chrome_options.add_argument("--incognito")
    chrome_options.add_argument("--disable-plugins-discovery");
    chrome_options.add_argument("--start-maximized")
    
    driver = webdriver.Chrome(options=chrome_options,service=service)
    driver.get('https://tinder.com')
    return driver

def main():
    driver = get_driver()
    flag = True
    while flag:
        try:
            driver.find_element('xpath','/html/body/div[1]/div/div[1]/div/main/div[1]/div/div/div/div/header/div/div[2]/div[2]/a').click()
            flag=False
        except:
            flag = True
         
    flag = True
    while flag:
        try:
            driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/div/div[3]/span/div[3]/button').click()
            flag=False
        except:
            flag = True
    

    flag = True
    while flag:
        try:
            driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/div/div[3]/span/div[3]/button').click()
            flag=False
        except:
            flag = True

#     flag = True
#     while flag:
#         try:
#             driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/div[2]/div/input').send_keys('8500402499')
#             flag=False
#         except:
#             flag = True
#     flag = True
#     while flag:
#         try:
#             driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/button').click()
#             flag=False
#         except:
#             flag = True
    
#     code = input('Enter the otp on your mobile')
#     for i in range(6):
#         driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/div[3]/input[i+1]').send_keys(code[i])
#         time.sleep(1)
#     driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/button').click()
#     try:
#         code = input('Enter the otp from you mail id received')
#         for i in range(6):
#             driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/div[3]/input[i]').send_keys(code[i])
#             time.sleep(1)
#         driver.find_element('xpath','/html/body/div[2]/div/div/div[1]/div/button').click()
#     except:
#         pass

# %%
main()
